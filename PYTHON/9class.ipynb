# %% [markdown]
# ### Class in Python
#
# A class is a blueprint or template used to create objects.
#
# It defines:
#
# Data/Properties → variables
# Behavior/Functions → methods
#
# Think of a class like a design of a car.
# The actual cars made from that design are objects.
#
# ## Syntax
#
#     class Classname:    -------> Classname first letter should be capital always and we can capital in mid agr hme lge ki hme ise capital krna h to kr skte h
#         pass

# %%
class Student:
    name = "Ritika"
    branch = "AIML"

# Here:
# Student → class name
# name and branch → attributes (variables inside class)

# %% [markdown]
# ### Python Class Notes
# | Topic                 | Description                                                        |
# | --------------------- | ------------------------------------------------------------------ |
# | **Class**             | A class is a blueprint used to create objects.                     |
# | **Object**            | An object is an instance of a class.                               |
# | **OOP**               | OOP stands for Object-Oriented Programming.                        |
# | **Syntax**            | `class ClassName:`                                                 |
# | **Constructor**       | `__init__()` is a special method used to initialize object values. |
# | **self Keyword**      | `self` refers to the current object of the class.                  |
# | **Method**            | A function inside a class is called a method.                      |
# | **Attribute**         | Variables inside a class are called attributes.                    |
# | **Instance Variable** | Variables created using `self` are instance variables.             |
# | **Object Creation**   | `obj = ClassName()`                                                |
# | **Advantages**        | Code reusability, better structure, easy maintenance.              |

# %% [markdown]
# # Pillars of OOP (Object-Oriented Programming)

# %% [markdown]
# | Pillar            | Definition                                                                                          | How Achieved                                                                        | Main Purpose                            | Main Keywords / Concepts                             | Example                               |
# | ----------------- | --------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------- | --------------------------------------- | ---------------------------------------------------- | ------------------------------------- |
# | **Encapsulation** | Wrapping data and methods together into a single unit (class) and restricting direct access to data | By using classes and access modifiers like public, protected, and private variables | Data security and organized code        | Class, Object, `self`, private variable (`__var`)    | `self.__marks = 90`                   |
# | **Inheritance**   | One class acquires properties and methods of another class                                          | By creating a child class from a parent class                                       | Code reusability and reduced redundancy | Parent class, Child class, `super()`                 | `class Dog(Animal)`                   |
# | **Polymorphism**  | Same method/operator behaves differently in different situations                                    | By method overriding, method overloading, and operator overloading                  | Flexibility and cleaner code            | Method overriding, overloading, operator overloading | `sound()` method in different classes |
# | **Abstraction**   | Hiding internal implementation details and showing only essential features                          | By using abstract classes and abstract methods                                      | Reduce complexity and improve security  | `ABC`, `@abstractmethod`                             | Abstract `Shape` class                |

# %%
class Classname:
    pass

# %%
class Student:
    pass
#class is keyword and student is class

# %%
class LastName:
    pass 

# first letter of LastName is capital and hme lga ki Name ka stating letter bhi capital hona chahiye
# to hmne name ka first letter bhi capital kr diya usme koi dikkat nhi h
# ab agr hm LN likhenge to usse hi hmare pass LastName as a suggestion aa jayega

# %%
class Student:
    name = "Ritika"   #class variable
    pass

# %%
class Student:
    name = "Ritika"

st = Student()    #st is object and we can create multiple object of a single class

# Student -> class
# st -> object
# name -> attribute (class variable)

# %%
class Student :
    name = "Ritika"
    classes = "Third Year"
    branch = "AIML"
    roll_number = "23EEMAL022"

st = Student()

# %%
st.branch    #object can access all class property through dot operator
# Out:
# 'AIML'

# %%
st.name
# Out:
# 'Ritika'

# %%
print(st.name)
# Out:
# Ritika

# %%
st.branch
st.name
st.roll_number     
#whole block will give block output as only roll number because it is a interpreter and interpreter work line by line and last line executed
# is roll number so only roll number is printed
# Out:
# '23EEMAL022'

# %%
#If we want to print all then  we have to pass them in print function
print(st.name)
print(st.branch)
print(st.roll_number)
# Out:
# Ritika
# AIML
# 23EEMAL022

# %%
class College:
    college_name="GWECA"
    college_address = "Ajmer"
    college_sp = 42

# we can create multiple object of a single class and these all objects can access all properties of the class
ritika = College()
riya = College()
hemant = College()

# %%
riya.college_name
# Out:
# 'GWECA'

# %%
ritika.college_address
# Out:
# 'Ajmer'

# %%
hemant.college_sp
# Out:
# 42

# %%
class College:
    college_name = "GWECA"
    def display():
        pass

clg = College()

# %%
clg.display()   #TypeError: College.display() takes 0 positional arguments but 1 was given

# %%
class College:
    college_name = "GWECA"
    def display(self):   #When we define a method in class we must have to pass atleast one argument in it ,
                         # by convention "self" is passed but if can be named anything 
        pass

clg = College()

# %%
clg.display()

# %%
class College:
    college_name = "GWECA"
    def display(a):   # by convention "self" is passed but if can be named anything 
        pass

clg = College()

# %%
clg.display()

# %%
# If we want to access class variable in a method in class we can access them using self keyword 
# Like by self.property

class College:
    college_name = "GWECA"
    college_address = "jaipur"
    college_sp = 42

    def show(self):
        print(self.college_name)
        print(self.college_address )
        print(self.college_sp)


clg = College()

# %%
clg.show()
# Out:
# GWECA
# jaipur
# 42

# %%
class A:
    def __init__(self,a,b):
        self.a = a
        self.b = b

class B(A):
    def __init__(self,a,b,aa,bb):
        super.__init__()
        self.aa = aa
        self.bb = bb

class C(B):
    def __init__(self,name,classes):
        self.name = name
        self.classes = classes


clg = C("ritika","3rd")
