# %%
class bmi_calculator:
    def __init__(self , height , weight):
        self.height = height
        self.weight = weight
        self.calculator()
            
    def calculator(self):
        bmi = self.weight/(self.height*self.height)
        print("BMI : ", bmi)

person1 = bmi_calculator(5,55)
# Out:
# BMI :  2.2
