# %% [markdown]
# ## Assignment :
# 1. Create a class Employee with attributes emp_name, emp_id, and salary.
# Create 3 objects and display their details.

# %%
class Employee :
    def __init__(self,emp_name,emp_id,salary):
        self.emp_name =  emp_name
        self.emp_id =  emp_id
        self.salary =  salary

    def display(self):
        print("Employee Name: ", self.emp_name , ", Employee Id: ", self.emp_id,
        ",Employee Salary: ", self.salary)

emp_1 = Employee("Aditi","8","2000000")
emp_1.display()
emp_2 = Employee("Ritika","18","50000000")
emp_2.display()
emp_3 = Employee("Yogita","29","4000000")
emp_3.display()
# Out:
# Employee Name:  Aditi , Employee Id:  8 ,Employee Salary:  2000000
# Employee Name:  Ritika , Employee Id:  18 ,Employee Salary:  50000000
# Employee Name:  Yogita , Employee Id:  29 ,Employee Salary:  4000000

# %% [markdown]
# 2. Create a class Calculator with methods for addition, subtraction,
# multiplication, and division.

# %%
class Calculator:
    def __init__(self,num1,num2):
        self.num1 = num1
        self.num2 = num2
        
    def add(self):
        print("Addition: ", self.num1 + self.num2) 

    def subtract(self):
        print("Subtraction: ", self.num1 - self.num2)
    
    def multiplication(self):
        print("Multiplication: ", self.num1 * self.num2) 
    
    def division(self):
        print("Division: ", self.num1 / self.num2)


calc = Calculator(24,2)
calc.add()
calc.subtract()
calc.multiplication()
calc.division()
# Out:
# Addition:  26
# Subtraction:  22
# Multiplication:  48
# Division:  12.0

# %% [markdown]
# 3. Create a class Book with a constructor to initialize title, author, and price,
# then print details.

# %%
class Book:
    def __init__(self,title,author,price):
        self.title = title
        self.author = author
        self.price = price
        self.display()

    def display(self):
        print("Title:",self.title , ",Author:", self.author , ",Price:", self.price)

book1 = Book("Atomic Habits", "James Clear ", "Rs.399")
book2 = Book("Ikigai", "Héctor García & Francesc Miralles ", "Rs.420")
# Out:
# Title: Atomic Habits ,Author: James Clear  ,Price: Rs.399
# Title: Ikigai ,Author: Héctor García & Francesc Miralles  ,Price: Rs.420

# %% [markdown]
# 4. Create a class Vehicle with method display(). Inherit it into class Car and
# call parent method.

# %%
class Vehicle:
    def __init__(self,brand):
        self.brand = brand

    def display(self):
        print("Brand : ", self.brand)

class Car(Vehicle):
    def __init__(self,brand,model):
        super().__init__(brand)
        self.model = model

    def show(self):
        print("Model : ", self.model)   

car = Car("Mercedes","GLC")
car.display()
car.show()
# Out:
# Brand :  Mercedes
# Model :  GLC

# %% [markdown]
# 5. Write a Python program using regex to find all digits from the string:
# "Python123Assignment456"

# %%
import re
text = "Python123Assignment456"
digits = re.findall(r'\d',text)

print("Extracted Digits:", digits)
# Out:
# Extracted Digits: ['1', '2', '3', '4', '5', '6']
