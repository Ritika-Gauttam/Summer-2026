# %% [markdown]
# OS operating system
# os is a module in python

# %% [markdown]
# 1. os.getcwd() ------> To get current working directories
# 2. os.listdir(path)  -----> To get current files in this path
# 3. os.mkdir("dir_name") ------> TO create a folder

# %% [markdown]
# | Function           | Work                          | Example                       |
# | ------------------ | ----------------------------- | ----------------------------- |
# | `os.getcwd()`      | Get current working directory | `os.getcwd()`                 |
# | `os.chdir(path)`   | Change current directory      | `os.chdir("D:/Python")`       |
# | `os.listdir()`     | Show all files and folders    | `os.listdir()`                |
# | `os.mkdir()`       | Create one folder             | `os.mkdir("Student")`         |
# | `os.makedirs()`    | Create multiple folders       | `os.makedirs("Data/Student")` |
# | `os.rmdir()`       | Delete empty folder           | `os.rmdir("Student")`         |
# | `os.removedirs()`  | Delete nested empty folders   | `os.removedirs("A/B/C")`      |
# | `os.remove()`      | Delete file                   | `os.remove("data.txt")`       |
# | `os.rename()`      | Rename file/folder            | `os.rename("old","new")`      |
# | `os.path.exists()` | Check file/folder exists      | `os.path.exists("Data")`      |
# | `os.path.isfile()` | Check file exists             | `os.path.isfile("a.txt")`     |
# | `os.path.isdir()`  | Check folder exists           | `os.path.isdir("Student")`    |
# | `os.path.join()`   | Join file paths               | `os.path.join("A","B")`       |

# %%
import os

# %%
# To get current working directories
os.getcwd()
# getcwd---->get current working directory
# Out:
# 'c:\\Users\\user\\OneDrive\\Desktop\\OS'

# %%
#To get current files in this path

path = r'c:\\Users\\user\\OneDrive\\Desktop\\OS' # r means row string
os.listdir(path)
# Out:
# ['basic.ipynb']

# %%
os.listdir(r'c:\\Users\\user\\OneDrive\\Desktop\\OS')
# Out:
# ['basic.ipynb']

# %%
os.listdir(r"C:\Users\user\OneDrive\Desktop\DSA C++")
# Out:
# ['.vscode',
#  '10_1Bitwise_Operators.cpp',
#  '10_2datatype_modifier.cpp',
#  '10_3_homework_problem.cpp',
#  '10_3_leetcode_problem_reverse_bits.cpp',
#  '11_1array.cpp',
#  '11_2pass_by_reference.cpp',
#  '11_3_linear_search.cpp',
#  '11_4_reverse_an_array.cpp',
#  '11_5_homework_problem.cpp',
#  '12_1_vector.cpp',
#  '12_2_vector_leetcode_problem1.cpp',
#  '12_3_vector_linear_search.cpp',
#  '12_4_reverse_vector.cpp',
#  '13_1Maximum_Subarray_sum.cpp',
#  "13_2_Kadane's_Algorithm.cpp",
#  '14_1_Pair_Sum_brute_force.cpp',
#  '14_2_Pair_Sum_Optimal.cpp',
#  '14_3_Majority_element_brute_force.cpp',
#  '14_4Majority_element_optimize.cpp',
#  "14_5_Boyer-Moore's Voting Algorithm.cpp",
#  '14_6_Majority_element.cpp',
#  '15_1_time__space_complexity.cpp',
#  '15_2_Common_time_complexities.ipynb',
#  '16_1_Compute_x^n.cpp',
#  '16_2_Buy_and_Sell_Stock.cpp',
#  '16_4_container_with_most_water.cpp',
#  '16_5_container_wth_max_water_brute_force.cpp',
# ...

# %%
# TO create a folder 
os.mkdir("hello")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\user\\OneDrive\\Desktop\\OS'

# %%
os.listdir(r'c:\\Users\\user\\OneDrive\\Desktop\\OS')
# Out:
# ['basic.ipynb', 'hello', 'students']

# %%
#To make more than one directories/folders
os.makedirs("students\\data\\reports")   #student folder k andr data folder or uske andr reports

# %%
os.listdir(os.getcwd())
# Out:
# ['basic.ipynb', 'hello', 'students']

# %%
#To remove a directory use rmdir
os.rmdir("hello")

# %%
os.listdir(os.getcwd())
# Out:
# ['basic.ipynb', 'students']

# %%
#To rename use os.rename("current_name","new_name")

os.rename("students","college")   #change name from students to college

# %%
os.listdir(os.getcwd())
# Out:
# ['basic.ipynb', 'college']

# %%
#To change directory use chdir 
os.chdir(r"C:\Users\user\OneDrive\Desktop\DATA SCIENCE UPFLAIR\PYTHON")   #change current directory to give directory path

# %%
os.getcwd()
# Out:
# 'C:\\Users\\user\\OneDrive\\Desktop\\DATA SCIENCE UPFLAIR\\PYTHON'

# %%
os.listdir(os.getcwd())
# Out:
# ['10_inheritance.ipynb',
#  '11_Encapsulation.ipynb',
#  '12_Constructor.ipynb',
#  '1strings.py',
#  '2list.py',
#  '3tuple.py',
#  '4dict.py',
#  '5operators.py',
#  '5set.py',
#  '6condition.ipynb',
#  '6conditional.ipynb',
#  '7looping.ipynb',
#  '8function.ipynb',
#  '9class.ipynb',
#  'basic.py']

# %%
os.chdir(r'c:\\Users\\user\\OneDrive\\Desktop\\OS')

# %%
os.getcwd()
# Out:
# 'c:\\Users\\user\\OneDrive\\Desktop\\OS'

# %%
path = r"C:\Users\user\OneDrive\Desktop\Federated_Learning\myapp\myapp\__pycache__"
os.listdir(path)
# Out:
# ['client_app.cpython-39.pyc',
#  'my_strategy.cpython-39.pyc',
#  'server_app.cpython-39.pyc',
#  'task.cpython-39.pyc',
#  '__init__.cpython-39.pyc']

# %% [markdown]
# ## JOINING PATHS

# %%
# path = r"C:\Users\user\OneDrive\Desktop\Federated_Learning\myapp\myapp\__pycache__"

path1 =r"C:\Users\user\OneDrive\Desktop\Federated_Learning"
path2 = r"myapp\myapp\__pycache__"
complete_path = os.path.join(path1,path2)
print(complete_path)
print("Final Output ", os.listdir(complete_path))
# Out:
# C:\Users\user\OneDrive\Desktop\Federated_Learning\myapp\myapp\__pycache__
# Final Output  ['client_app.cpython-39.pyc', 'my_strategy.cpython-39.pyc', 'server_app.cpython-39.pyc', 'task.cpython-39.pyc', '__init__.cpython-39.pyc']

# %%
#To check is this file present in this directory
os.path.isfile(r"C:\Users\user\OneDrive\Desktop\OS\basic.ipynb")
# Out:
# True

# %%
os.path.isfile(r"c:\\Users\\user\\OneDrive\\Desktop\\OS")   #this is not a file it is a directory
# Out:
# False

# %%
os.path.isfile(r"C:\Users\user\OneDrive\Desktop\DATA SCIENCE UPFLAIR\Assignments\assignment1.py")
# Out:
# True

# %%
#To check is this directory present 
os.path.isdir('c:\\Users\\user\\OneDrive\\Desktop\\OS')
# Out:
# True

# %%
os.path.isdir(r"C:\Users\user\OneDrive\Desktop\Federated_Learning\myapp\myapp\__pycache__")
# Out:
# True

# %%
#To check if this path exists use path.exists
os.path.exists(r"C:\Users\user\OneDrive\Desktop\OS\basic.ipynb")
# Out:
# True

# %%
os.path.exists(r"C:\Users\user\OneDrive\Desktop\Federated_Learning\myapp\myapp\__pycache__")
# Out:
# True

# %%
# To get size of path
os.path.getsize(r"C:\Users\user\OneDrive\Desktop\OS\basic.ipynb")

# This checks:
#“How large is the file basic.ipynb?” and returns its size in bytes.
# Out:
# 16613
