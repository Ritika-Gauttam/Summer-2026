# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("loan_approval.csv")

# %%
df
# Out:
#                  name              city  income  credit_score  loan_amount  \
# 0        Allison Hill         East Jill  113810           389        39698
# 1        Brandon Hall     New Jamesside   44592           729        15446
# 2        Rhonda Smith      Lake Roberto   33278           584        11189
# 3     Gabrielle Davis  West Melanieview  127196           344        48823
# 4        Valerie Gray         Mariastad   66048           496        47174
# ...               ...               ...     ...           ...          ...
# 1995   James Schaefer         Robertton   92163           770        12251
# 1996        Diana Lin         New Frank   38799           635        48259
# 1997    Brandon Meyer        East Haley   41957           763        16752
# 1998      Jason Price          Adamland  139022           360        24031
# 1999     Nicole Brown    New Nathantown   41188           482        31397
#
#       years_employed  points  loan_approved
# ...

# %%
df.columns
# Out:
# Index(['name', 'city', 'income', 'credit_score', 'loan_amount',
#        'years_employed', 'points', 'loan_approved'],
#       dtype='str')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# name              0
# city              0
# income            0
# credit_score      0
# loan_amount       0
# years_employed    0
# points            0
# loan_approved     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            2000 non-null   str
#  1   city            2000 non-null   str
#  2   income          2000 non-null   int64
#  3   credit_score    2000 non-null   int64
#  4   loan_amount     2000 non-null   int64
#  5   years_employed  2000 non-null   int64
#  6   points          2000 non-null   float64
#  7   loan_approved   2000 non-null   bool
# dtypes: bool(1), float64(1), int64(4), str(2)
# memory usage: 111.5 KB

# %%
loan_approved_dict={True: 'Approved',False: 'Rejected'}
df['loan_approved'] = df['loan_approved'].map(loan_approved_dict)

# %%
sns.countplot(data= df, x = 'loan_approved')
plt.title("Number of approved vs rejected loans")
# Out:
# Text(0.5, 1.0, 'Number of approved vs rejected loans')

# %%
sns.boxplot(x='loan_approved', y='income', data=df)
plt.title('Income vs Loan Approval')
plt.show()

# %%
sns.boxplot( x = 'loan_approved' , y = 'credit_score',data = df )
plt.title('Credit Score vs Loan Approval')
plt.show()

# %%
sns.histplot(data=df,x='credit_score',hue='loan_approved')
plt.title('Credit Score vs Loan Approval')
plt.show()

# %%
sns.boxplot(x='loan_approved', y='loan_amount', data=df)
plt.title('Credit Score vs Loan Approval')
plt.show()

# %%
sns.boxplot(x='loan_approved', y='years_employed', data=df)
plt.title('Years Employed vs Loan Approval')
plt.show()

# %%
df['loan_approved'] = df['loan_approved'].map({
    'Rejected': 0,
    'Approved': 1
})

# %%
sns.heatmap(df.corr(numeric_only=True),
            annot=True,
            cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
df['name'].unique()
# Out:
# <StringArray>
# [        'Allison Hill',         'Brandon Hall',         'Rhonda Smith',
#       'Gabrielle Davis',         'Valerie Gray',       'Darren Roberts',
#            'Holly Wood',      'Nicholas Martin',          'Patty Perez',
#            'Emily Rios',
#  ...
#        'Rebecca Newman', 'Christopher Morrison',        'Sierra Gentry',
#         'Hannah Carter',          'Ryan Thomas',       'James Schaefer',
#             'Diana Lin',        'Brandon Meyer',          'Jason Price',
#          'Nicole Brown']
# Length: 2000, dtype: str

# %%
name_dict ={'Allison Hill':1,         'Brandon Hall':2,         'Rhonda Smith':3,
        'Gabrielle Davis':4,         'Valerie Gray':5,       'Darren Roberts':6,
        'Holly Wood':7,      'Nicholas Martin':8,          'Patty Perez':9,
        'Emily Rios':10, 'Rebecca Newman':11 , 'Christopher Morrison':12,        'Sierra Gentry':13,
        'Hannah Carter':14,      'Ryan Thomas':15,       'James Schaefer':16,
        'Diana Lin':17 ,        'Brandon Meyer':18,       'Jason Price':19,
        'Nicole Brown':20}

# %%
df['name'] = df['name'].map(name_dict)

# %%
df['city'].unique()
# Out:
# <StringArray>
# [       'East Jill',    'New Jamesside',     'Lake Roberto',
#  'West Melanieview',        'Mariastad',  'Port Jesseville',
#       'Lake Joseph',       'Nelsonside',  'Port Leslieview',
#    'Wilkersonmouth',
#  ...
#     'South Kenneth',        'Cookshire',     'Jenniferstad',
#           'Basston',        'Tylertown',        'Robertton',
#         'New Frank',       'East Haley',         'Adamland',
#    'New Nathantown']
# Length: 1882, dtype: str

# %%
# from sklearn.preprocessing import LabelEncoder

# le = LabelEncoder()
# df['city'] = le.fit_transform(df['city'])

# %%
city_dict = {'East Jill':1,    'New Jamesside':2,  'Lake Roberto':3,
            'West Melanieview':4,        'Mariastad':5,  'Port Jesseville':6,
            'Lake Joseph':7,  'Nelsonside':8, 'Port Leslieview':9,
            'Wilkersonmouth':10, 'South Kenneth':11,  'Cookshire':12,     'Jenniferstad':13,
            'Basston':14,   'Tylertown':15,        'Robertton':16,
            'New Frank':17, 'East Haley':18,   'Adamland':19,
            'New Nathantown':20}

df['city'] = df['city'].map(city_dict)

# %%
df['loan_approved'].unique()
# Out:
# array([0, 1])

# %%
loan_approved_dict = {True : 1 , False : 2}
df['loan_approved'] = df['loan_approved'].map(loan_approved_dict)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            20 non-null     float64
#  1   city            22 non-null     float64
#  2   income          2000 non-null   int64
#  3   credit_score    2000 non-null   int64
#  4   loan_amount     2000 non-null   int64
#  5   years_employed  2000 non-null   int64
#  6   points          2000 non-null   float64
#  7   loan_approved   0 non-null      float64
# dtypes: float64(4), int64(4)
# memory usage: 125.1 KB

# %%
x = df['loan_approved']
x
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1995   NaN
# 1996   NaN
# 1997   NaN
# 1998   NaN
# 1999   NaN
# Name: loan_approved, Length: 2000, dtype: float64

# %%
y = df.drop(['loan_approved'],axis = 1)
y
# Out:
#       name  city  income  credit_score  loan_amount  years_employed  points
# 0      1.0   1.0  113810           389        39698              27    50.0
# 1      2.0   2.0   44592           729        15446              28    55.0
# 2      3.0   3.0   33278           584        11189              13    45.0
# 3      4.0   4.0  127196           344        48823              29    50.0
# 4      5.0   5.0   66048           496        47174               4    25.0
# ...    ...   ...     ...           ...          ...             ...     ...
# 1995  16.0  16.0   92163           770        12251              13    85.0
# 1996  17.0  17.0   38799           635        48259              17    40.0
# 1997  18.0  18.0   41957           763        16752               5    60.0
# 1998  19.0  19.0  139022           360        24031              35    55.0
# 1999  20.0  20.0   41188           482        31397               6    20.0
#
# [2000 rows x 7 columns]

# %%
df.isna().sum()
# Out:
# name              1980
# city              1978
# income               0
# credit_score         0
# loan_amount          0
# years_employed       0
# points               0
# loan_approved     2000
# dtype: int64
